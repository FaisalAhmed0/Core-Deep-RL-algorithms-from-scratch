# %%
import matplotlib.pyplot
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('-DQN-env=PongNoFrameskip-v4-lr=0.0001-Buffer size:10000-Batch size:32-no.iteration:3000000-seed:0.csv')

# %%
sns.lineplot(range(len(df['Training return'])), df['Training return'])

# %%
sns.lineplot(range(len(df['Training return'])), df['Epsilon'])
